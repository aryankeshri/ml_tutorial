# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('bought_insurance')
plt.scatter(df.age, df.bought_insurance, color='red',marker='.')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1)

# %%
X_test.shape
# Out:
# (3, 1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1], dtype=int64)

# %%
y_test
# Out:
# 11    0
# 6     0
# 25    1
# Name: bought_insurance, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_proba(X_test)
# Out:
# array([[0.7953057 , 0.2046943 ],
#        [0.04147722, 0.95852278],
#        [0.04862935, 0.95137065]])

# %%
model.predict([[50]])
# Out:
# D:\kworking\Aryan\GenAI\env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
